# %% [markdown]
# # 🧠 SegForge Interactive Annotator - Cloud Instance
# Run the cells below to initialize the Segment Anything Model (SAM) based app directly in your Colab or Kaggle environment.
# It will automatically clone the repository, install its dependencies, and launch a public interface link.

# %%
# !git clone https://github.com/oaboelazm/SegForge.git
# %cd SegForge
# !pip install -r requirements.txt -q

# %%
# --- Launch Gradio (Recommended for Cloud) ---
# !python app.py

# --- Launch Streamlit (Alternative) ---
# To use Streamlit on Colab, uncomment the lines below, and comment out the Gradio lines above.
# !npm install -g localtunnel
# !streamlit run app_streamlit.py & npx localtunnel --port 8501
